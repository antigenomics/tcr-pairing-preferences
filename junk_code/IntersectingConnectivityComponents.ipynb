# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import itertools
import networkx as nx

# %matplotlib inline

# %%
data_pd = pd.read_csv('data/MergedData.csv', index_col=0)
data_pd = data_pd.loc[data_pd['species'] == 'HomoSapiens']
data_pd = data_pd.loc[data_pd['database'] == 'tcr_ab_pairs']
data_pd.index = np.arange(data_pd.shape[0])

# %%
acdr3 = data_pd['alpha.cdr3'].as_matrix()
bcdr3 = data_pd['beta.cdr3'].as_matrix()
acdr3_length = np.array([len(x) for x in acdr3])
bcdr3_length = np.array([len(x) for x in bcdr3])

# %%
def aapClusters(sequences, indexing, mmm=1, delimeter='*'):
    l = len(sequences[0])
    clusters = []
    masks = itertools.combinations(np.arange(l), mmm)
    for mask in masks:
        mask = [-1] + list(mask) + [l]
        masker = lambda x: delimeter.join([x[mask[i] + 1:mask[i + 1]] for i in range(mmm + 1)])
        factor = set([masker(x) for x in sequences])
        c = {m:[] for m in factor}
        for i, x in enumerate(sequences):
            c[masker(x)].append(indexing[i])
        for m in factor:
            if len(c[m]) > 1:
                clusters.append(c[m])
    return clusters

def EdgeListfromClusters(n, clusters):
    edges = set([])
    for cluster in clusters:
        for x, y in itertools.combinations(cluster, 2):
            edges.add((x, y))
    return list(edges)

# %%
aedges = []
for l in range(6, 20):
    indexes = np.arange(acdr3.shape[0])[acdr3_length == l]
    a = acdr3[indexes]
    clusters = aapClusters(a, indexes)
    e = EdgeListfromClusters(acdr3.shape[0], clusters)
    aedges += e

bedges = []
for l in range(6, 20):
    indexes = np.arange(bcdr3.shape[0])[bcdr3_length == l]
    b = bcdr3[indexes]
    clusters = aapClusters(b, indexes)
    e = EdgeListfromClusters(bcdr3.shape[0], clusters)
    bedges += e

# %%
Agraph = nx.Graph()
Agraph.add_edges_from(aedges)
acomponents = list(nx.connected_components(Agraph))

Bgraph = nx.Graph()
Bgraph.add_edges_from(bedges)
bcomponents = list(nx.connected_components(Bgraph))

alength = np.array([len(x) for x in acomponents])
acomp = np.array(acomponents)[alength > 100]

blength = np.array([len(x) for x in bcomponents])
bcomp = np.array(bcomponents)[blength > 100]

# %%
i2acomp = {}
for i, x in enumerate(acomp):
    for y in x:
        i2acomp[y] = i
i2bcomp = {}
for i, x in enumerate(bcomp):
    for y in x:
        i2bcomp[y] = i

avertexes = set(i2acomp.keys())
bvertexes = set(i2bcomp.keys())
indexes = avertexes & bvertexes

vacomp = np.array([indexes & acomp[i] for i in range(acomp.shape[0])])
vbcomp = np.array([indexes & bcomp[i] for i in range(bcomp.shape[0])])

comp_table = np.zeros((len(acomp), len(bcomp)), dtype=int)
for i in indexes:
    comp_table[i2acomp[i], i2bcomp[i]] += 1

xcompsum, ycompsum = np.sum(comp_table, axis=1), np.sum(comp_table, axis=0)
expected = np.dot(xcompsum.reshape(-1, 1), ycompsum.reshape(1, -1)) / np.sum(comp_table)
zscores = (comp_table - expected) / np.sqrt(expected + 1)
zscore5 = np.array(np.where(zscores > 5)).T
for i, j in zscore5:
    print(i, j, zscores[i, j])
# Out:
# 163 5 5.68641385603

# %%
a_cluster, b_cluster = zscore5[0]

aind = np.array(list(vacomp[a_cluster]))
bind = np.array(list(vbcomp[b_cluster]))
pind = np.array(list(vacomp[a_cluster] & vbcomp[b_cluster]))
print('alpha chain={}\n'.format(aind.shape[0]), 
      'beta chain={}\n'.format(bind.shape[0]), 
      'Paired={}\n'.format(len(acomp[a_cluster] & bcomp[b_cluster])))
data_pd.loc[pind]
# Out:
# alpha chain=291
#  beta chain=130
#  Paired=10
#             database      species sample epitope antigen tissue cell_subset  \
# 12865   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 99974   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 105550  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 33070   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 14810   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 4852    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 73397   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 8982    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 58778   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 115963  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j       alpha.cdr3    beta.v beta.d   beta.j  \
# 12865   TRAV21  TRAJ45  CAVRLSGGGADGLTF  TRBV20-1    NaN  TRBJ2-7
# 99974   TRAV39  TRAJ45  CAVGQSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-5
# 105550  TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-3
# 33070   TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-7
# 14810   TRAV21  TRAJ45  CAVRAAGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-1
# 4852    TRAV39  TRAJ45  CAVGSSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
# 73397   TRAV21  TRAJ45  CAVRRPGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-7
# 8982    TRAV39  TRAJ45  CAVGSSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
# 58778   TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-5
# 115963  TRAV39  TRAJ45  CAVGGSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
#
#            beta.cdr3
# 12865   CSARPGGYEQYF
# 99974   CSARVAGETQYF
# 105550  CSARASGTTQYF
# 33070   CSARTTGYEQYF
# 14810   CSARPGGYEQFF
# 4852    CSARVSGETQYF
# 73397   CSARPGGYEQYF
# 8982    CSARWAGETQYF
# 58778   CSARLAGETQYF
# 115963  CSARQSGETQYF

# %% [markdown]
# What we get with all databases:
#
# The epitope-related clusters dominate.

# %%
a_cluster, b_cluster = zscore5[1]

aind = np.array(list(vacomp[a_cluster]))
bind = np.array(list(vbcomp[b_cluster]))
pind = np.array(list(vacomp[a_cluster] & vbcomp[b_cluster]))
print('alpha chain={}\n'.format(aind.shape[0]), 
      'beta chain={}\n'.format(bind.shape[0]), 
      'Paired={}\n'.format(len(acomp[a_cluster] & bcomp[b_cluster])))
data_pd.loc[pind]
# Out:
# alpha chain=335
#  beta chain=331
#  Paired=17
#               database      species sample    epitope antigen tissue  \
# 85059   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 85540   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 157636  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL     NaN   PBMC
# 145347  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL     NaN   PBMC
# 70343   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 34475   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 122637  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 111726  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 141231  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 67281     tcr_ab_pairs  HomoSapiens      3        NaN     NaN    NaN
# 56851     tcr_ab_pairs  HomoSapiens      3        NaN     NaN    NaN
# 19540   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 83060   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 146550  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 33848   vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL      M1   PBMC
# 153595  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL     NaN   PBMC
# 157023  vdjdb_ab,vdjdb  HomoSapiens    NaN  GILGFVFTL     NaN   PBMC
#
#        cell_subset    alpha.v    alpha.j      alpha.cdr3               beta.v  \
# 85059         CD8+  TRAV27*01  TRAJ42*01  CAGAGGGSQGNLIF            TRBV19*01
# 85540         CD8+  TRAV27*01  TRAJ42*01  CAGGDGGSQGNLIF            TRBV19*02
# 157636         NaN  TRAV27*01        NaN  CAGAGGGSQGNLIF            TRBV19*01
# 145347         NaN  TRAV27*01        NaN  CAGADGGSQGNLIF            TRBV19*01
# 70343         CD8+  TRAV27*01  TRAJ42*01  CAGAEGGSQGNLIF            TRBV19*01
# 34475         CD8+  TRAV27*01  TRAJ42*01  CAGAEGGSQGNLIF            TRBV19*01
# 122637        CD8+  TRAV27*01  TRAJ42*01  CAGAGGGSQGNLIF            TRBV19*01
# 111726        CD8+  TRAV27*01  TRAJ42*01  CAGADGGSQGNLIF            TRBV19*01
# 141231        CD8+  TRAV27*01  TRAJ42*01  CAGAYGGSQGNLIF            TRBV19*02
# 67281          NaN    TRAV8-3     TRAJ42  CAVDAAGSQGNLIF    TRBV12-4,TRBV12-3
# 56851          NaN     TRAV21     TRAJ42  CAVSSGGSQGNLIF               TRBV27
# 19540         CD8+  TRAV27*01  TRAJ42*01  CAGADGGSQGNLIF            TRBV19*01
# 83060         CD8+  TRAV27*01  TRAJ42*01  CAGADGGSQGNLIF  TRBV19*02,TRBV19*01
# 146550        CD8+  TRAV27*01  TRAJ42*01  CAGADGGSQGNLIF            TRBV19*01
# 33848         CD8+  TRAV27*01  TRAJ42*01  CAGAGGGSQGNLIF            TRBV19*01
# 153595         NaN  TRAV27*01        NaN  CAGAGGGSQGNLIF            TRBV19*01
# 157023         NaN  TRAV25*01        NaN  CAGNYGGSQGNLIF            TRBV19*01
#
#              beta.d      beta.j      beta.cdr3
# 85059           NaN  TRBJ2-2*01  CASSSRATGELFF
# 85540           NaN  TRBJ2-2*01  CASSIRSTGELFF
# 157636          NaN         NaN  CASSSRSTGELFF
# 145347          NaN         NaN  CASSIRSTGELFF
# 70343           NaN  TRBJ2-2*01  CASSIRSTGELFF
# 34475           NaN  TRBJ2-2*01  CASSGRSTGELFF
# 122637          NaN  TRBJ2-2*01  CASSKRSTGELFF
# 111726          NaN  TRBJ2-2*01  CASSSRSAGELFF
# 141231          NaN  TRBJ2-2*01  CASSIRSTGELFF
# 67281   TRBD1,TRBD2     TRBJ2-2  CASNRDTTGELFF
# 56851   TRBD2,TRBD1     TRBJ2-2  CASSFPGAGELFF
# 19540           NaN  TRBJ2-2*01  CASSISSTGELFF
# 83060           NaN  TRBJ2-2*01  CASSGRAAGELFF
# 146550          NaN  TRBJ2-2*01  CASSGRSAGELFF
# 33848           NaN  TRBJ2-2*01  CASSIRATGELFF
# 153595          NaN         NaN  CASSIRSTGELFF
# 157023          NaN         NaN  CASSVRSTGELFF

# %%
a_cluster, b_cluster = zscore5[2]

aind = np.array(list(vacomp[a_cluster]))
bind = np.array(list(vbcomp[b_cluster]))
pind = np.array(list(vacomp[a_cluster] & vbcomp[b_cluster]))
print('alpha chain={}\n'.format(aind.shape[0]), 
      'beta chain={}\n'.format(bind.shape[0]), 
      'Paired={}\n'.format(len(acomp[a_cluster] & bcomp[b_cluster])))
data_pd.loc[pind]
# Out:
# alpha chain=84
#  beta chain=522
#  Paired=10
#               database      species sample              epitope antigen  \
# 31843   vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV     NaN
# 111815  vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV     NaN
# 154631  vdjdb_ab,vdjdb  HomoSapiens    NaN  NLVPMVATV,GILGFVFTL      M1
# 127083  vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV    pp65
# 78093   vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV     NaN
# 10062   vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV    pp65
# 150063  vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV     NaN
# 38385   vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV     NaN
# 15098   vdjdb_ab,vdjdb  HomoSapiens    NaN            NLVPMVATV    pp65
# 110108    tcr_ab_pairs  HomoSapiens      3                  NaN     NaN
#
#                   tissue cell_subset    alpha.v    alpha.j      alpha.cdr3  \
# 31843               PBMC        CD8+  TRAV25*01  TRAJ50*01  CAGPMKTSYDKVIF
# 111815              PBMC        CD8+  TRAV25*01  TRAJ50*01  CAGPMKTSYDKVIF
# 154631  PBMC,TCL culture        CD8+  TRAV35*01  TRAJ50*01  CAGPMKTSYDKVIF
# 127083              PBMC        CD8+  TRAV35*01  TRAJ50*01  CAGPRETSYDKVIF
# 78093               PBMC        CD8+  TRAV25*01  TRAJ50*01  CAGPRKTSYDKVIF
# 10062               PBMC        CD8+  TRAV35*01  TRAJ50*01  CAGPMKTSYDKVIF
# 150063              PBMC        CD8+  TRAV25*01  TRAJ50*01  CAGPRQTSYDKVIF
# 38385               PBMC        CD8+  TRAV25*01  TRAJ50*01  CAGPEKTSYDKVIF
# 15098               PBMC        CD8+  TRAV35*01  TRAJ50*01  CAGPRETSYDKVIF
# 110108               NaN         NaN  TRAV29DV5     TRAJ50  CAASQKTSYDKVIF
#
#              beta.v beta.d      beta.j     beta.cdr3
# 31843   TRBV11-1*01    NaN  TRBJ1-1*01  CASSSAHYGYTF
# 111815  TRBV11-1*01    NaN  TRBJ1-1*01  CASSSAFYGYTF
# 154631  TRBV12-4*01    NaN  TRBJ1-2*01  CASSSANYGYTF
# 127083  TRBV12-4*01    NaN  TRBJ1-2*01  CASSSAYYGYTF
# 78093   TRBV11-1*01    NaN  TRBJ1-1*01  CASSSANYGYTF
# 10062   TRBV12-4*01    NaN  TRBJ1-2*01  CASASANYGYTF
# 150063  TRBV11-1*01    NaN  TRBJ1-1*01  CASSSANYGYTF
# 38385   TRBV11-1*01    NaN  TRBJ1-1*01  CASSSANYGYTF
# 15098   TRBV12-4*01    NaN  TRBJ1-2*01  CASASANYGYTF
# 110108       TRBV27  TRBD2     TRBJ1-2  CASSLGGYGYTF

# %%
a_cluster, b_cluster = zscore5[3]

aind = np.array(list(vacomp[a_cluster]))
bind = np.array(list(vbcomp[b_cluster]))
pind = np.array(list(vacomp[a_cluster] & vbcomp[b_cluster]))
print('alpha chain={}\n'.format(aind.shape[0]), 
      'beta chain={}\n'.format(bind.shape[0]), 
      'Paired={}\n'.format(len(acomp[a_cluster] & bcomp[b_cluster])))
data_pd.loc[pind]
# Out:
# alpha chain=301
#  beta chain=131
#  Paired=10
#             database      species sample epitope antigen tissue cell_subset  \
# 117475  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 106915  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 74344   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 13034   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 33486   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 9102    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 4917    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 14998   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 101244  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 59551   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j       alpha.cdr3    beta.v beta.d   beta.j  \
# 117475  TRAV39  TRAJ45  CAVGGSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
# 106915  TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-3
# 74344   TRAV21  TRAJ45  CAVRRPGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-7
# 13034   TRAV21  TRAJ45  CAVRLSGGGADGLTF  TRBV20-1    NaN  TRBJ2-7
# 33486   TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-7
# 9102    TRAV39  TRAJ45  CAVGSSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
# 4917    TRAV39  TRAJ45  CAVGSSGGGADGLTF  TRBV20-1    NaN  TRBJ2-5
# 14998   TRAV21  TRAJ45  CAVRAAGGGADGLTF  TRBV20-1  TRBD1  TRBJ2-1
# 101244  TRAV39  TRAJ45  CAVGQSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-5
# 59551   TRAV39  TRAJ45  CAVGRSGGGADGLTF  TRBV20-1  TRBD2  TRBJ2-5
#
#            beta.cdr3
# 117475  CSARQSGETQYF
# 106915  CSARASGTTQYF
# 74344   CSARPGGYEQYF
# 13034   CSARPGGYEQYF
# 33486   CSARTTGYEQYF
# 9102    CSARWAGETQYF
# 4917    CSARVSGETQYF
# 14998   CSARPGGYEQFF
# 101244  CSARVAGETQYF
# 59551   CSARLAGETQYF
