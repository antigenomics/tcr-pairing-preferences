# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import itertools
import networkx as nx
from scipy.stats import poisson

# %matplotlib inline

# %%
data_pd = pd.read_csv('data/MergedData.csv', index_col=0)
data_pd = data_pd.loc[data_pd['species'] == 'HomoSapiens']
data_pd = data_pd.loc[data_pd['database'] == 'tcr_ab_pairs']
# data_pd.index = np.arange(data_pd.shape[0])

# %%
antiindex = np.zeros((1 + data_pd.index[-1]), dtype=int)
for i, x in enumerate(data_pd.index):
    antiindex[x] = i

# %%
vgene_grouper = {'TRAV12-1':'TRAV12', 'TRAV12-2':'TRAV12', 'TRAV12-3':'TRAV12'}

vgene_lists = data_pd['alpha.v'].values
for i in range(vgene_lists.shape[0]):
    vgenes = vgene_lists[i].split(',')
    for j in range(len(vgenes)):
        if vgenes[j] in vgene_grouper:
            vgenes[j] = vgene_grouper[vgenes[j]]
    vgene_lists[i] = ','.join(list(set(vgenes)))

data_pd['alpha.v'] = vgene_lists

# %%
acdr3 = data_pd['alpha.cdr3'].values
bcdr3 = data_pd['beta.cdr3'].values
acdr3_length = np.array([len(x) for x in acdr3])
bcdr3_length = np.array([len(x) for x in bcdr3])

# %%
auseless_positions = {7: [6],
 8: [2],
 9: [1],
 10: [4, 9],
 11: [2, 4, 10],
 12: [2, 11],
 13: [4],
 14: [4, 13],
 15: [4],
 16: [4, 5, 15],
 17: [4, 6, 16],
 18: [5, 6, 17],
 19: [4]}

buseless_positions = {7: [],
 8: [],
 9: [2],
 10: [4, 9],
 11: [4, 6],
 12: [4, 11],
 13: [4],
 14: [4, 5, 6, 13],
 15: [4, 14],
 16: [4, 15],
 17: [4, 16],
 18: [7, 8, 11, 17],
 19: []}

# %%
acdr3f = np.zeros((acdr3.shape[0]), dtype=object)
for i in range(acdr3.shape[0]):
    arr = np.array(list(acdr3[i]))
    if len(arr) in auseless_positions.keys():
        arr[auseless_positions[len(arr)]] = 'X'
    acdr3f[i] = ''.join(arr)
    
bcdr3f = np.zeros((bcdr3.shape[0]), dtype=object)
for i in range(bcdr3.shape[0]):
    arr = np.array(list(bcdr3[i]))
    if len(arr) in buseless_positions.keys():
        arr[buseless_positions[len(arr)]] = 'X'
    bcdr3f[i] = ''.join(arr)

acdr3 = acdr3f
bcdr3 = bcdr3f

# %%
def aapClusters(sequences, indexing, mmm=1, delimeter='*'):
    l = len(sequences[0])
    clusters = []
    masks = itertools.combinations(np.arange(l), mmm)
    for mask in masks:
        mask = [-1] + list(mask) + [l]
        masker = lambda x: delimeter.join([x[mask[i] + 1:mask[i + 1]] for i in range(mmm + 1)])
        factor = set([masker(x) for x in sequences])
        c = {m:[] for m in factor}
        for i, x in enumerate(sequences):
            c[masker(x)].append(indexing[i])
        for m in factor:
            if len(c[m]) > 1:
                clusters.append(c[m])
    return clusters

def EdgeListfromClusters(n, clusters):
    edges = set([])
    for cluster in clusters:
        for x, y in itertools.combinations(cluster, 2):
            edges.add((x, y))
    return list(edges)

# %%
aedges = []
for l in range(6, 20):
    indexes = np.arange(acdr3.shape[0])[acdr3_length == l]
    a = acdr3[indexes]
    clusters = aapClusters(a, indexes)
    e = EdgeListfromClusters(acdr3.shape[0], clusters)
    aedges += e

bedges = []
for l in range(6, 20):
    indexes = np.arange(bcdr3.shape[0])[bcdr3_length == l]
    b = bcdr3[indexes]
    clusters = aapClusters(b, indexes)
    e = EdgeListfromClusters(bcdr3.shape[0], clusters)
    bedges += e

# %%
aadj = [[] for i in range(acdr3.shape[0])]
badj = [[] for i in range(acdr3.shape[0])]

for i in aedges:
    aadj[i[0]].append(i[1])
    aadj[i[1]].append(i[0])

for i in bedges:
    badj[i[0]].append(i[1])
    badj[i[1]].append(i[0])

# %%
superadj = [list(set(aadj[i]) & set(badj[i]))for i in range(acdr3.shape[0])]

# %%
superdeg = np.array([len(x) for x in superadj])
multdeg = np.array([len(aadj[i]) * len(badj[i]) for i in range(acdr3.shape[0])])

# %%
max(multdeg), max(superdeg)
# Out:
# (1012860, 9)

# %%
superratio = sum(superdeg) / sum(multdeg)

# %%
e = superratio * multdeg + 1
cdf = poisson.cdf(k=superdeg, mu=e)

# %%
aa = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y', 'X']
aa2num = {aa[i]:i for i in range(21)}

class PWM:
    def __init__(self, sequences):
        assert len(sequences) > 0
        self.l = len(sequences[0])
        PPM = np.ones((self.l, 21), dtype=float)
        for seq in sequences:
            assert len(seq) == self.l
            for pos in range(self.l):
                PPM[pos, aa2num[seq[pos]]] += 1
        self.PWM = np.log2(PPM)
    
    def Score(self, seq):
        assert self.l == len(seq)
        return sum([self.PWM[pos, aa2num[seq[pos]]] for pos in range(self.l)])

# %%
m = 14

anchor_indexes = np.argsort(cdf)[-m:]
anchor_indexes
# Out:
# array([ 13671, 124947, 168881, 160368, 107865,  47074, 118403, 157116,
#         35720,  18048,  35001,  64398,  26329,  89920])

# %%
scores = np.zeros((m))
ship_indexes = np.zeros((m), dtype=object)
a_count, b_count = np.zeros((m)), np.zeros((m))

# %%
for i in range(m):
    center = anchor_indexes[i]

    core = np.concatenate([superadj[center], [center]])

    pwm_a = PWM(acdr3[core])
    pwm_b = PWM(bcdr3[core])

    indexes_bool = [(len(acdr3[j]) == len(acdr3[center])) & 
                    (len(bcdr3[j]) == len(bcdr3[center])) for j in range(acdr3.shape[0])]
    indexes = np.where(indexes_bool)[0]
    acdr3i = acdr3[indexes]
    bcdr3i = bcdr3[indexes]

    ascores = np.array([pwm_a.Score(a) for a in acdr3i])
    bscores = np.array([pwm_b.Score(b) for b in bcdr3i])

    ascores = ascores - max(ascores)
    bscores = bscores - max(bscores)

    maxscore = 0
    maxathr, maxbthr = 0, 0
    for athr, bthr in itertools.product(np.arange(-10, 0), np.arange(-10, 0)):
        a, b = np.where(ascores > athr)[0], np.where(bscores > bthr)[0]
        indx = np.array(list(set(a) & set(b)))
        mu = a.shape[0] * b.shape[0] / acdr3i.shape[0]
        score = poisson.cdf(k=indx.shape[0], mu=mu)
        if maxscore < score:
            maxathr, maxbthr = athr, bthr
            maxscore = score

    athr, bthr = maxathr, maxbthr
    a, b = np.where(ascores > athr)[0], np.where(bscores > bthr)[0]
    indx = np.array(list(set(a) & set(b)))
    mu = a.shape[0] * b.shape[0] / acdr3i.shape[0]
    score = poisson.cdf(k=indx.shape[0], mu=mu)

    scores[i] = score
    ship_indexes[i] = indexes[indx]
    a_count[i] = a.shape[0]
    b_count[i] = b.shape[0]

# %%
data_pd.loc[data_pd.index[ship_indexes[1]]]
# Out:
#             database      species sample epitope antigen tissue cell_subset  \
# 155298  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 47694   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 20520   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 159057  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 127941  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 162439  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 167053  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 168937  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j      alpha.cdr3   beta.v       beta.d   beta.j  \
# 155298  TRAV25  TRAJ11  CAGPVNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 47694   TRAV25  TRAJ11  CAGPSNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 20520   TRAV25  TRAJ11  CAGPINSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 159057  TRAV25  TRAJ11  CAGGVNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 127941  TRAV25  TRAJ11  CAGPVNSGYSTLTF  TRBV7-9  TRBD2,TRBD1  TRBJ2-1
# 162439  TRAV25  TRAJ11  CAGPTNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 167053  TRAV25  TRAJ11  CAGPQNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 168937  TRAV25  TRAJ11  CAGPGNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
#
#              beta.cdr3   index
# 155298  CASSLAGSYNEQFF  155298
# 47694   CASSLAGSYNEQFF   47694
# 20520   CASSLAGSYNEQFF   20520
# 159057  CASSLAGSYNEQFF  159057
# 127941  CASSLAGTYNEQFF  127941
# 162439  CASSLSGSYNEQFF  162439
# 167053  CASSLAGSYNEQFF  167053
# 168937  CASSLAGSYNEQFF  168937

# %%
ind = [155298, 47694, 20520, 159057, 127941, 162439, 167053, 168937]
core = antiindex[ind]

# %%
pwm_a = PWM(acdr3[core])
pwm_b = PWM(bcdr3[core])

indexes_bool = [(len(acdr3[j]) == len(acdr3[core[0]])) & 
                (len(bcdr3[j]) == len(bcdr3[core[0]])) for j in range(acdr3.shape[0])]
indexes = np.where(indexes_bool)[0]
acdr3i = acdr3[indexes]
bcdr3i = bcdr3[indexes]

ascores = np.array([pwm_a.Score(a) for a in acdr3i])
bscores = np.array([pwm_b.Score(b) for b in bcdr3i])

ascores = ascores - max(ascores)
bscores = bscores - max(bscores)

maxscore = 0
maxathr, maxbthr = 0, 0
for athr, bthr in itertools.product(np.arange(-10, 0), np.arange(-10, 0)):
    a, b = np.where(ascores > athr)[0], np.where(bscores > bthr)[0]
    indx = np.array(list(set(a) & set(b)))
    mu = a.shape[0] * b.shape[0] / acdr3i.shape[0]
    score = poisson.cdf(k=indx.shape[0], mu=mu)
    if maxscore < score:
        maxathr, maxbthr = athr, bthr
        maxscore = score

athr, bthr = maxathr, maxbthr
a, b = np.where(ascores > athr)[0], np.where(bscores > bthr)[0]
indx = np.array(list(set(a) & set(b)))
mu = a.shape[0] * b.shape[0] / acdr3i.shape[0]
score = poisson.cdf(k=indx.shape[0], mu=mu)

# %%
indexes

# %%
a.shape[0], b.shape[0], mu, indx.shape[0], acdr3i.shape[0]
# Out:
# (9, 69, 0.06700474751834268, 8, 9268)

# %%
indx_set = set(indx)
for i in a:
    if not i in indx_set:
        print(data_pd.index[indexes[i]])
# Out:
# 161003

# %%
data_pd.loc[data_pd.index[indexes[a]]]
# Out:
#             database      species sample epitope antigen tissue cell_subset  \
# 20520   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 47694   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 127941  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 155298  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 159057  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 161003  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 162439  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 167053  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 168937  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j      alpha.cdr3                   beta.v       beta.d  \
# 20520   TRAV25  TRAJ11  CAGPINSGYSTLTF                  TRBV7-9          NaN
# 47694   TRAV25  TRAJ11  CAGPSNSGYSTLTF                  TRBV7-9          NaN
# 127941  TRAV25  TRAJ11  CAGPVNSGYSTLTF                  TRBV7-9  TRBD2,TRBD1
# 155298  TRAV25  TRAJ11  CAGPVNSGYSTLTF                  TRBV7-9          NaN
# 159057  TRAV25  TRAJ11  CAGGVNSGYSTLTF                  TRBV7-9          NaN
# 161003  TRAV27  TRAJ11  CAGGGNSGYSTLTF  TRBV5-6,TRBV5-7,TRBV5-5  TRBD2,TRBD1
# 162439  TRAV25  TRAJ11  CAGPTNSGYSTLTF                  TRBV7-9          NaN
# 167053  TRAV25  TRAJ11  CAGPQNSGYSTLTF                  TRBV7-9          NaN
# 168937  TRAV25  TRAJ11  CAGPGNSGYSTLTF                  TRBV7-9          NaN
#
#          beta.j       beta.cdr3
# 20520   TRBJ2-1  CASSLAGSYNEQFF
# 47694   TRBJ2-1  CASSLAGSYNEQFF
# 127941  TRBJ2-1  CASSLAGTYNEQFF
# 155298  TRBJ2-1  CASSLAGSYNEQFF
# 159057  TRBJ2-1  CASSLAGSYNEQFF
# 161003  TRBJ1-2  CASSLGTAIYGYTF
# 162439  TRBJ2-1  CASSLSGSYNEQFF
# 167053  TRBJ2-1  CASSLAGSYNEQFF
# 168937  TRBJ2-1  CASSLAGSYNEQFF

# %%
trbv79 = data_pd['beta.v'] == 'TRBV7-9'
trav25 = data_pd['alpha.v'] == 'TRAV25'
traj11 = data_pd['alpha.j'] == 'TRAJ11'
e = np.sum(trbv79) * np.sum(trav25) / data_pd.shape[0]
print(np.sum(trbv79), np.sum(trav25), np.sum(trbv79 & trav25), data_pd.shape[0], e)
# data_pd.loc[trav25 & trbv79 & traj11]
# Out:
# 5251 3459 120 169568 107.1146029911304
#             database      species sample epitope antigen tissue cell_subset  \
# 20520   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 47694   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 64808   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 127941  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 155298  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 159057  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 162439  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 167053  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 168937  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j      alpha.cdr3   beta.v       beta.d   beta.j  \
# 20520   TRAV25  TRAJ11  CAGPINSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 47694   TRAV25  TRAJ11  CAGPSNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 64808   TRAV25  TRAJ11   CAGPSEGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 127941  TRAV25  TRAJ11  CAGPVNSGYSTLTF  TRBV7-9  TRBD2,TRBD1  TRBJ2-1
# 155298  TRAV25  TRAJ11  CAGPVNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 159057  TRAV25  TRAJ11  CAGGVNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 162439  TRAV25  TRAJ11  CAGPTNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 167053  TRAV25  TRAJ11  CAGPQNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
# 168937  TRAV25  TRAJ11  CAGPGNSGYSTLTF  TRBV7-9          NaN  TRBJ2-1
#
#              beta.cdr3
# 20520   CASSLAGSYNEQFF
# 47694   CASSLAGSYNEQFF
# 64808   CASSLAGSYNEQFF
# 127941  CASSLAGTYNEQFF
# 155298  CASSLAGSYNEQFF
# 159057  CASSLAGSYNEQFF
# 162439  CASSLSGSYNEQFF
# 167053  CASSLAGSYNEQFF
# 168937  CASSLAGSYNEQFF

# %%
print('trav25', np.sum(trav25))
print('traj11', np.sum(traj11))
print('trbv79', np.sum(trbv79))

e = np.sum(trav25) * np.sum(traj11) / data_pd.shape[0]
print('trav25 & traj11', np.sum(trav25 & traj11), ';expected=', e)
e = np.sum(trbv79) * np.sum(traj11) / data_pd.shape[0]
print('traj11 & trbv79', np.sum(traj11 & trbv79), ';expected=', e)
e = np.sum(trav25) * np.sum(trbv79) / data_pd.shape[0]
print('trbv79 & trav25', np.sum(trbv79 & trav25), ';expected=', e)

e = np.sum(trav25) * np.sum(trbv79) * np.sum(traj11) / data_pd.shape[0] ** 2
print('trbv79 & trav25 & traj11', np.sum(trav25 & trbv79 & traj11), ';expected=', e)
# Out:
# trav25 3459
# traj11 2694
# trbv79 5251
# trav25 & traj11 61 ;expected= 54.95462587280619
# traj11 & trbv79 91 ;expected= 83.42490328363843
# trbv79 & trav25 120 ;expected= 107.1146029911304
# trbv79 & trav25 & traj11 9 ;expected= 1.7017759274043764

# %% [markdown]
# Also let's note that trbj becomes also fixed.

# %%
data_pd.loc[data_pd.index[indexes[b]]]
# Out:
#             database      species sample epitope antigen tissue cell_subset  \
# 1263    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 4119    tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 5252    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 5377    tcr_ab_pairs  HomoSapiens      5     NaN     NaN    NaN         NaN
# 9525    tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 14606   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 20194   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 20304   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 20520   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 22774   tcr_ab_pairs  HomoSapiens      5     NaN     NaN    NaN         NaN
# 23250   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 26085   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 30832   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 38883   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 40078   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 47694   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 54281   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 57875   tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 60721   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 61986   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 63789   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 69702   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 79013   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 79892   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 82397   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 84425   tcr_ab_pairs  HomoSapiens      5     NaN     NaN    NaN         NaN
# 87783   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 95668   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 96524   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 97381   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# ...              ...          ...    ...     ...     ...    ...         ...
# 127941  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 130757  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 131403  tcr_ab_pairs  HomoSapiens      5     NaN     NaN    NaN         NaN
# 132066  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 133682  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 139148  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 139333  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 140160  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 141555  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 142194  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 143188  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 144210  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 145888  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 148625  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 151430  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 152267  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 155298  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 155598  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 158685  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 158776  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 159057  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 159700  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 161320  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 161939  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 162439  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 167053  tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 168098  tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 168937  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 173173  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 173484  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#                 alpha.v alpha.j      alpha.cdr3  \
# 1263           TRAV13-2  TRAJ12  CAEPHLDSSYKLIF
# 4119             TRAV12  TRAJ24  CVVNFDDSWGKLQF
# 5252              TRAV6  TRAJ49  CALGGGRAGNQFYF
# 5377           TRAV13-2  TRAJ23  CAENGNNQGGKLIF
# 9525            TRAV8-1  TRAJ16  CAVIGRSDGQKLLF
# 14606           TRAV1-1  TRAJ11  CAVRSILGYSTLTF
# 20194             TRAV3  TRAJ11  CAVRDLTGYSTLTF
# 20304            TRAV35  TRAJ52  CAGHGGTSYGKLTF
# 20520            TRAV25  TRAJ11  CAGPINSGYSTLTF
# 22774            TRAV12  TRAJ15  CAMSARQAGTALIF
# 23250         TRAV29DV5  TRAJ26  CAASQRSYGQNFVF
# 26085             TRAV4  TRAJ40  CLVDALSGTYKYIF
# 30832            TRAV12  TRAJ53  CAVNVGGSNYKLTF
# 38883            TRAV27  TRAJ40  CAGFPFSGTYKYIF
# 40078            TRAV20  TRAJ43  CAVQGPVNNNDMRF
# 47694            TRAV25  TRAJ11  CAGPSNSGYSTLTF
# 54281            TRAV22  TRAJ44  CAVEWDGTASKLTF
# 155298                                  TRBV7-9          NaN  TRBJ2-1
# 155598                                   TRBV28          NaN  TRBJ2-1
# 158685                                   TRBV13          NaN  TRBJ2-1
# 158776                          TRBV7-2,TRBV7-8          NaN  TRBJ2-1
# 159057                                  TRBV7-9          NaN  TRBJ2-1
# 159700                                   TRBV28          NaN  TRBJ2-1
# 161320                                  TRBV7-2        TRBD2  TRBJ2-1
# 161939                                   TRBV28        TRBD2  TRBJ2-1
# 162439                                  TRBV7-9          NaN  TRBJ2-1
# 167053                                  TRBV7-9          NaN  TRBJ2-1
# 168098                                    TRBV2  TRBD2,TRBD1  TRBJ2-1
# 168937                                  TRBV7-9          NaN  TRBJ2-1
# 173173                          TRBV7-3,TRBV7-4          NaN  TRBJ2-1
# 173484                                 TRBV25-1          NaN  TRBJ2-1
#
#              beta.cdr3
# 1263    CASSRGDSYNEQFF
# 4119    CASSGGSSYNEQFF
# 5252    CASSQDLSYNEQFF
# 5377    CASSTRSSYNEQFF
# 9525    CASSYSGSYNEQFF
# 14606   CASSLDSSYNEQFF
# 20194   CASSDRGSYNEQFF
# 20304   CASSRDITYNEQFF
# 20520   CASSLAGSYNEQFF
# 22774   CASSRQSSYNEQFF
# 23250   CASSQVPSYNEQFF
# 26085   CASSLGASYNEQFF
# 30832   CASSDLTTYNEQFF
# 38883   CASSSGGSYNEQFF
# 40078   CASSVAETYNEQFF
# 47694   CASSLAGSYNEQFF
# 54281   CASSSSGSYNEQFF
# 57875   CASSLDVTYNEQFF
# 60721   CASSFSSSYNEQFF
# 61986   CASSEWVTYNEQFF
# 63789   CASSWSSSYNEQFF
# 69702   CASSPRSSYNEQFF
# 79013   CASSSWGSYNEQFF
# 79892   CASSLTESYNEQFF
# 82397   CASSLIRSYNEQFF
# 84425   CASSLESSYNEQFF
# 87783   CASSLDFSYNEQFF
# 95668   CASSGQGSYNEQFF
# 96524   CASSLEHSYNEQFF
# 97381   CASSVAGTYNEQFF
# ...                ...
# 127941  CASSLAGTYNEQFF
# 130757  CASSPDDSYNEQFF
# 131403  CASSEESSYNEQFF
# 132066  CASSNPASYNEQFF
# 133682  CASSYGISYNEQFF
# 139148  CASSHGSSYNEQFF
# 139333  CASSLIRSYNEQFF
# 140160  CASSQAGSYNEQFF
# 141555  CASSKSGTYNEQFF
# 142194  CASSPPSSYNEQFF
# 143188  CASSPSKSYNEQFF
# 144210  CASSPSGSYNEQFF
# 145888  CASSNTGTYNEQFF
# 148625  CASSRSGSYNEQFF
# 151430  CASSLYSTYNEQFF
# 152267  CASSLETTYNEQFF
# 155298  CASSLAGSYNEQFF
# 155598  CASSSSTTYNEQFF
# 158685  CASSREDTYNEQFF
# 158776  CASSPRSSYNEQFF
# 159057  CASSLAGSYNEQFF
# 159700  CASSFRDSYNEQFF
# 161320  CASSWGLSYNEQFF
# 161939  CASSFEGTYNEQFF
# 162439  CASSLSGSYNEQFF
# 167053  CASSLAGSYNEQFF
# 168098  CASSSFGTYNEQFF
# 168937  CASSLAGSYNEQFF
# 173173  CASSLAQTYNEQFF
# 173484  CASSVGISYNEQFF
#
# [69 rows x 14 columns]

# %%
data_pd.loc[data_pd.index[ship_indexes[5]]]
# Out:
#             database      species sample epitope antigen tissue cell_subset  \
# 164239  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 123359  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 155197  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 13985   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 48185   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 21210   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 110435  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 13043   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 172951  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#          alpha.v alpha.j        alpha.cdr3  beta.v beta.d   beta.j  \
# 164239  TRAV13-1  TRAJ52  CAASLSGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 123359  TRAV13-1  TRAJ52  CAASFSGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 155197  TRAV13-1  TRAJ52  CAASIFGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 13985   TRAV13-1  TRAJ52  CAASLAGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 48185   TRAV13-1  TRAJ52  CAASLAGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 21210   TRAV13-1  TRAJ52  CAASLSGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 110435  TRAV13-1  TRAJ52  CAAVLRGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 13043   TRAV13-1  TRAJ52  CAASLNGGTSYGKLTF  TRBV27  TRBD1  TRBJ1-2
# 172951  TRAV13-1  TRAJ52  CAASLYGGTSYGKLTF  TRBV27    NaN  TRBJ1-2
#
#             beta.cdr3   index
# 164239  CASSFDRQYGYTF  164239
# 123359  CASSFDRADGYTF  123359
# 155197  CASSVDRNYGYTF  155197
# 13985   CASSFDRSYGYTF   13985
# 48185   CASSFDRAYGYTF   48185
# 21210   CASSFDRNYGYTF   21210
# 110435  CASSFDRSYGYTF  110435
# 13043   CASSFDRNYGYTF   13043
# 172951  CASSFDRTYGYTF  172951

# %%
data_pd.loc[data_pd.index[ship_indexes[6]]]
# Out:
#             database      species sample epitope antigen tissue cell_subset  \
# 65932   tcr_ab_pairs  HomoSapiens      2     NaN     NaN    NaN         NaN
# 35812   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 160904  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 26923   tcr_ab_pairs  HomoSapiens    3,2     NaN     NaN    NaN         NaN
# 92065   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 36547   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 18458   tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
# 121246  tcr_ab_pairs  HomoSapiens      3     NaN     NaN    NaN         NaN
#
#        alpha.v alpha.j   alpha.cdr3                                   beta.v  \
# 65932   TRAV12  TRAJ26  CVVGYGQNFVF                                    TRBV9
# 35812   TRAV12  TRAJ26  CVEVYGQNFVF  TRBV4-1,TRBV4-3,TRBV4-2,TRBV4-1,TRBV4-3
# 160904  TRAV12  TRAJ26  CVVSYGQNFVF                          TRBV4-1,TRBV4-3
# 26923   TRAV12  TRAJ26  CVSSYGQNFVF                                    TRBV9
# 92065   TRAV12  TRAJ26  CVGVYGQNFVF                                    TRBV9
# 36547   TRAV12  TRAJ26  CVAPYGQNFVF                                    TRBV9
# 18458   TRAV12  TRAJ26  CVVLYGQNFVF                          TRBV5-4,TRBV5-8
# 121246  TRAV12  TRAJ26  CVGNYGQNFVF                                  TRBV4-1
#
#        beta.d   beta.j      beta.cdr3   index
# 65932     NaN  TRBJ1-2  CASSVDPNYGYTF   65932
# 35812     NaN  TRBJ1-2  CASSQDGNYGYTF   35812
# 160904    NaN  TRBJ1-2  CASSQDGNYGYTF  160904
# 26923     NaN  TRBJ1-2  CASSVDPNYGYTF   26923
# 92065     NaN  TRBJ1-2  CASSEDPNYGYTF   92065
# 36547     NaN  TRBJ1-2  CASSVDGNYGYTF   36547
# 18458     NaN  TRBJ1-2  CASSPDGNYGYTF   18458
# 121246    NaN  TRBJ1-2  CASSQDGNYGYTF  121246

# %% [markdown]
# Other 11 group are clones of these three.
